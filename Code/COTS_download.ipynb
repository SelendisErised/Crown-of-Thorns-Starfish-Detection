# %% [markdown]
# # Kaggle - Help to Protect the Great Barrier Reef

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Dataset downloading
# This notebook helps to download COTS dataset from kaggle api to your google drive, storing the data at *datapath* (/content/drive/MyDrive/Protect_Reef)

# %% [markdown]
# **TO DO: obtain your kaggle.json from your profile in kaggle.com and upload it to colab content/**

# %%
! pip install kaggle
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
import os
# Check current working directory
print(os.getcwd())
# Change the working directory
datapath = '/content/drive/MyDrive/Protect_Reef_test'
# !mkdir -p {datapath}
os.chdir(datapath)
print(os.getcwd())

# %%
# Download dataset
! kaggle competitions download -c tensorflow-great-barrier-reef

# %%
! unzip tensorflow-great-barrier-reef.zip

# %%
! rm -rf tensorflow-great-barrier-reef.zip
